# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Data Wrangling**

# %% [markdown]
# In this notebook, we will perform the following:

# %% [markdown]
# *   Identify duplicate values in the dataset.
#
# *   Remove duplicate values from the dataset.
#
# *   Identify missing values in the dataset.
#
# *   Impute the missing values in the dataset.
#
# *   Normalize data in the dataset.

# %% [markdown]
# Firstly, we import pandas module.

# %%
import pandas as pd

# %% [markdown]
# We load the dataset into a dataframe.

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m1_survey_data.csv")
df
# Out:
#        Respondent                      MainBranch Hobbyist  \
# 0               4  I am a developer by profession       No
# 1               9  I am a developer by profession      Yes
# 2              13  I am a developer by profession      Yes
# 3              16  I am a developer by profession      Yes
# 4              17  I am a developer by profession      Yes
# ...           ...                             ...      ...
# 11547       25136  I am a developer by profession      Yes
# 11548       25137  I am a developer by profession      Yes
# 11549       25138  I am a developer by profession      Yes
# 11550       25141  I am a developer by profession      Yes
# 11551       25142  I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# 0                                                  Never
# 1                             Once a month or more often
# 2      Less than once a month but more than once per ...
# 3                                                  Never
# 4      Less than once a month but more than once per ...
# ...                                                  ...
# 11547                                              Never
# 11548                                              Never
# 11549                            Less than once per year
# 11550  Less than once a month but more than once per ...
# 11551  Less than once a month but more than once per ...
#
#                                               OpenSource          Employment  \
# 0      The quality of OSS and closed source software ...  Employed full-time
# 1      The quality of OSS and closed source software ...  Employed full-time
# 2      OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 3      The quality of OSS and closed source software ...  Employed full-time
# 4      The quality of OSS and closed source software ...  Employed full-time
# ...                                                  ...                 ...
# 11547  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 11548  The quality of OSS and closed source software ...  Employed full-time
# 11549  The quality of OSS and closed source software ...  Employed full-time
# 11550  OSS is, on average, of LOWER quality than prop...  Employed full-time
# 11551  OSS is, on average, of HIGHER quality than pro...  Employed full-time
#
#               Country Student  \
# 0       United States      No
# 1         New Zealand      No
# 2       United States      No
# 3      United Kingdom      No
# 4           Australia      No
# ...               ...     ...
# 11547   United States      No
# 11548          Poland      No
# 11549   United States      No
# 11550     Switzerland      No
# 11551  United Kingdom      No
#
#                                                  EdLevel  \
# 0               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1      Some college/university study without earning ...
# 2            Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 3            Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 4               Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...                                                  ...
# 11547        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 11548        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 11549        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 11550  Secondary school (e.g. American high school, G...
# 11551          Other doctoral degree (Ph.D, Ed.D., etc.)
#
#                                           UndergradMajor  ...  \
# 0      Computer science, computer engineering, or sof...  ...
# 1      Computer science, computer engineering, or sof...  ...
# 2      Computer science, computer engineering, or sof...  ...
# 3                                                    NaN  ...
# 4      Computer science, computer engineering, or sof...  ...
# ...                                                  ...  ...
# 11547  Computer science, computer engineering, or sof...  ...
# 11548  Computer science, computer engineering, or sof...  ...
# 11549  Computer science, computer engineering, or sof...  ...
# 11550                                                NaN  ...
# 11551  A natural science (ex. biology, chemistry, phy...  ...
#
#                                   WelcomeChange  \
# 0       Just as welcome now as I felt last year
# 1       Just as welcome now as I felt last year
# 2      Somewhat more welcome now than last year
# 3       Just as welcome now as I felt last year
# 4       Just as welcome now as I felt last year
# ...                                         ...
# 11547   Just as welcome now as I felt last year
# 11548     A lot more welcome now than last year
# 11549     A lot more welcome now than last year
# 11550  Somewhat less welcome now than last year
# 11551   Just as welcome now as I felt last year
#
#                                             SONewContent   Age Gender Trans  \
# 0      Tech articles written by other developers;Indu...  22.0    Man    No
# 1                                                    NaN  23.0    Man    No
# 2      Tech articles written by other developers;Cour...  28.0    Man    No
# 3      Tech articles written by other developers;Indu...  26.0    Man    No
# 4      Tech articles written by other developers;Indu...  29.0    Man    No
# ...                                                  ...   ...    ...   ...
# 11547  Tech articles written by other developers;Cour...  36.0    Man    No
# 11548  Tech articles written by other developers;Tech...  25.0    Man    No
# 11549  Tech articles written by other developers;Indu...  34.0    Man    No
# 11550                                                NaN  25.0    Man    No
# 11551  Tech articles written by other developers;Tech...  30.0    Man    No
#
#                      Sexuality                              Ethnicity  \
# 0      Straight / Heterosexual           White or of European descent
# 1                     Bisexual           White or of European descent
# 2      Straight / Heterosexual           White or of European descent
# 3      Straight / Heterosexual           White or of European descent
# 4      Straight / Heterosexual  Hispanic or Latino/Latina;Multiracial
# ...                        ...                                    ...
# 11547  Straight / Heterosexual           White or of European descent
# 11548  Straight / Heterosexual           White or of European descent
# 11549  Straight / Heterosexual           White or of European descent
# 11550  Straight / Heterosexual           White or of European descent
# 11551                 Bisexual           White or of European descent
#
#       Dependents           SurveyLength                  SurveyEase
# 0             No  Appropriate in length                        Easy
# 1             No  Appropriate in length  Neither easy nor difficult
# 2            Yes  Appropriate in length                        Easy
# 3             No  Appropriate in length  Neither easy nor difficult
# 4             No  Appropriate in length                        Easy
# ...          ...                    ...                         ...
# 11547         No  Appropriate in length                   Difficult
# 11548         No  Appropriate in length  Neither easy nor difficult
# 11549        Yes               Too long                        Easy
# 11550         No  Appropriate in length                        Easy
# 11551         No  Appropriate in length                        Easy
#
# [11552 rows x 85 columns]

# %% [markdown]
# ## Finding duplicates

# %% [markdown]
# We find how many duplicate rows exist in the dataframe.

# %%
duplicated_rows = df[df.duplicated()]
len(duplicated_rows)
# Out:
# 0

# %% [markdown]
# ## Removing duplicates

# %% [markdown]
# Let's remove the duplicate rows from the dataframe.

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# We verify if duplicates were actually dropped.

# %%
len(duplicated_rows)
# Out:
# 0

# %% [markdown]
# ## Finding Missing values

# %% [markdown]
# We find the missing values for all columns.

# %%
import numpy as np
missing_data = df.isnull()
missing_data
# Out:
#        Respondent  MainBranch  Hobbyist  OpenSourcer  OpenSource  Employment  \
# 0           False       False     False        False       False       False
# 1           False       False     False        False       False       False
# 2           False       False     False        False       False       False
# 3           False       False     False        False       False       False
# 4           False       False     False        False       False       False
# ...           ...         ...       ...          ...         ...         ...
# 11547       False       False     False        False       False       False
# 11548       False       False     False        False       False       False
# 11549       False       False     False        False       False       False
# 11550       False       False     False        False       False       False
# 11551       False       False     False        False       False       False
#
#        Country  Student  EdLevel  UndergradMajor  ...  WelcomeChange  \
# 0        False    False    False           False  ...          False
# 1        False    False    False           False  ...          False
# 2        False    False    False           False  ...          False
# 3        False    False    False            True  ...          False
# 4        False    False    False           False  ...          False
# ...        ...      ...      ...             ...  ...            ...
# 11547    False    False    False           False  ...          False
# 11548    False    False    False           False  ...          False
# 11549    False    False    False           False  ...          False
# 11550    False    False    False            True  ...          False
# 11551    False    False    False           False  ...          False
#
#        SONewContent    Age  Gender  Trans  Sexuality  Ethnicity  Dependents  \
# 0             False  False   False  False      False      False       False
# 1              True  False   False  False      False      False       False
# 2             False  False   False  False      False      False       False
# 3             False  False   False  False      False      False       False
# 4             False  False   False  False      False      False       False
# ...             ...    ...     ...    ...        ...        ...         ...
# 11547         False  False   False  False      False      False       False
# 11548         False  False   False  False      False      False       False
# 11549         False  False   False  False      False      False       False
# 11550          True  False   False  False      False      False       False
# 11551         False  False   False  False      False      False       False
#
#        SurveyLength  SurveyEase
# 0             False       False
# 1             False       False
# 2             False       False
# 3             False       False
# 4             False       False
# ...             ...         ...
# 11547         False       False
# 11548         False       False
# 11549         False       False
# 11550         False       False
# 11551         False       False
#
# [11398 rows x 85 columns]

# %% [markdown]
# We can find out how many rows are missing in the column 'WorkLoc'

# %%
#Counting missing values for a single column

print('WorkLoc')
print (missing_data['WorkLoc'].value_counts())
# Out:
# WorkLoc
# False    11366
# True        32
# Name: WorkLoc, dtype: int64

# %%
#Counting missing values for all columns

print('Column  No of Missing Values')
for column in df.columns:
  print(f'{column}  {df[column].isnull().sum()}')
# Out:
# Column  No of Missing Values
# Respondent  0
# MainBranch  0
# Hobbyist  0
# OpenSourcer  0
# OpenSource  81
# Employment  0
# Country  0
# Student  51
# EdLevel  112
# UndergradMajor  737
# EduOther  164
# OrgSize  96
# DevType  65
# YearsCode  9
# Age1stCode  13
# YearsCodePro  16
# CareerSat  0
# JobSat  1
# MgrIdiot  493
# MgrMoney  497
# MgrWant  493
# JobSeek  0
# LastHireDate  0
# LastInt  413
# FizzBuzz  37
# JobFactors  3
# ResumeUpdate  39
# CurrencySymbol  0
# CurrencyDesc  0
# CompTotal  809
# CompFreq  206
# ConvertedComp  816
# WorkWeekHrs  122
# WorkPlan  121
# WorkChallenge  164
# WorkRemote  8
# WorkLoc  32
# ImpSyn  5
# CodeRev  1
# CodeRevHrs  2426
# UnitTests  29
# PurchaseHow  196
# PurchaseWhat  38
# LanguageWorkedWith  11
# LanguageDesireNextYear  134
# DatabaseWorkedWith  453
# DatabaseDesireNextYear  1042
# PlatformWorkedWith  411
# PlatformDesireNextYear  544
# WebFrameWorkedWith  1393
# WebFrameDesireNextYear  1617
# MiscTechWorkedWith  2182
# MiscTechDesireNextYear  1455
# DevEnviron  29
# OpSys  34
# Containers  82
# BlockchainOrg  2322
# BlockchainIs  2610
# BetterLife  98
# ITperson  35
# OffOn  38
# SocialMedia  293
# Extraversion  20
# ScreenName  507
# SOVisit1st  325
# SOVisitFreq  5
# SOVisitTo  1
# SOFindAnswer  3
# SOTimeSaved  50
# SOHowMuchTime  1917
# SOAccount  1
# SOPartFreq  1128
# SOJobs  6
# EntTeams  5
# SOComm  0
# WelcomeChange  85
# SONewContent  1965
# Age  287
# Gender  73
# Trans  123
# Sexuality  542
# Ethnicity  675
# Dependents  140
# SurveyLength  19
# SurveyEase  14

# %% [markdown]
# ## Imputing missing values

# %% [markdown]
# We find the  value counts for the column WorkLoc.

# %%
df['WorkLoc'].value_counts()
# Out:
# Office                                            6806
# Home                                              3589
# Other place, such as a coworking space or cafe     971
# Name: WorkLoc, dtype: int64

# %% [markdown]
# We identify the value that is most frequent (majority) in the WorkLoc column.

# %%
#The most frequent value in WorkLoc column is Office

# %% [markdown]
# #### The most frequent value in WorkLoc column is Office

# %% [markdown]
# So, we impute (replace) all the empty rows in the column WorkLoc with the value that you have identified as majority.

# %%
df['WorkLoc'].replace(np.nan, 'Office', inplace=True)

# %% [markdown]
# After imputation there should ideally not be any empty rows in the WorkLoc column.

# %% [markdown]
# We verify if imputing was successful.

# %%
print(df['WorkLoc'].isnull().value_counts())
print('\n')
df['WorkLoc'].value_counts()
# Out:
# False    11398
# Name: WorkLoc, dtype: int64
# Office                                            6838
# Home                                              3589
# Other place, such as a coworking space or cafe     971
# Name: WorkLoc, dtype: int64

# %% [markdown]
# What is the majority category under the column **Employment**?

# %%
df['Employment'].value_counts().iloc[[0]]
# Out:
# Employed full-time    10968
# Name: Employment, dtype: int64

# %% [markdown]
# Under the column " UndergradMajor", which category has the minimum number of rows?

# %%
df['UndergradMajor'].value_counts().iloc[[-1]]
# Out:
# A health science (ex. nursing, pharmacy, radiology)    24
# Name: UndergradMajor, dtype: int64

# %% [markdown]
# The column ‘ConvertedComp’ contains the annual compensation of the survey respondents. What is the best approach to impute the missing values in this column?

# %%
df['ConvertedComp'].describe()
# Out:
# count    1.058200e+04
# mean     1.315967e+05
# std      2.947865e+05
# min      0.000000e+00
# 25%      2.686800e+04
# 50%      5.774500e+04
# 75%      1.000000e+05
# max      2.000000e+06
# Name: ConvertedComp, dtype: float64

# %% [markdown]
# ##### Median is the best approach to impute the missing values in the column

# %% [markdown]
# ## Normalizing data

# %% [markdown]
# There are two columns in the dataset that talk about compensation.
#
# One is "CompFreq". This column shows how often a developer is paid (Yearly, Monthly, Weekly).
#
# The other is "CompTotal". This column talks about how much the developer is paid per Year, Month, or Week depending upon his/her "CompFreq".
#
# This makes it difficult to compare the total compensation of the developers.
#
# In this section we will create a new column called 'NormalizedAnnualCompensation' which contains the 'Annual Compensation' irrespective of the 'CompFreq'.
#
# Once this column is ready, it makes comparison of salaries easy.

# %% [markdown]
# We start with listing out the various categories in the column 'CompFreq'

# %%
df['CompFreq'].unique()
# Out:
# array(['Yearly', 'Monthly', 'Weekly', nan], dtype=object)

# %% [markdown]
# We create a new column named 'NormalizedAnnualCompensation', using the below logic to arrive at the values for the column NormalizedAnnualCompensation.
#
# If the CompFreq is Yearly then use the exising value in CompTotal.
#
# If the CompFreq is Monthly then multiply the value in CompTotal with 12 (months in an year).
#
# If the CompFreq is Weekly then multiply the value in CompTotal with 52 (weeks in an year).

# %%
norm_annual_comp = []

for i in range(len(df)):

    if df['CompFreq'].iloc[i] == 'Weekly':
        norm_annual_comp.append(df['CompTotal'].iloc[i]*52)
    elif df['CompFreq'].iloc[i] == 'Monthly':
        norm_annual_comp.append(df['CompTotal'].iloc[i]*12)
    else:
        norm_annual_comp.append(df['CompTotal'].iloc[i]*1)

df['NormalizedAnnualCompensation']= norm_annual_comp
df.sample(5)
# Out:
#       Respondent                      MainBranch Hobbyist  \
# 3472        7302  I am a developer by profession       No
# 5858       12504  I am a developer by profession      Yes
# 3765        7954  I am a developer by profession      Yes
# 8455       18258  I am a developer by profession      Yes
# 1546        3036  I am a developer by profession      Yes
#
#                                             OpenSourcer  \
# 3472                                              Never
# 5858                            Less than once per year
# 3765                            Less than once per year
# 8455  Less than once a month but more than once per ...
# 1546                            Less than once per year
#
#                                              OpenSource          Employment  \
# 3472  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 5858  The quality of OSS and closed source software ...  Employed full-time
# 3765  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 8455  The quality of OSS and closed source software ...  Employed full-time
# 1546  The quality of OSS and closed source software ...  Employed full-time
#
#                  Country         Student  \
# 3472         Philippines              No
# 5858       United States              No
# 3765             Germany              No
# 8455  Dominican Republic              No
# 1546              Canada  Yes, full-time
#
#                                                 EdLevel  \
# 3472           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 5858           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3765           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 8455  Some college/university study without earning ...
# 1546           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                          UndergradMajor  ...  \
# 3472  A natural science (ex. biology, chemistry, phy...  ...
# 5858  Computer science, computer engineering, or sof...  ...
# 3765  Information systems, information technology, o...  ...
# 8455                      Web development or web design  ...
# 1546  Computer science, computer engineering, or sof...  ...
#
#                                            SONewContent   Age Gender Trans  \
# 3472  Tech articles written by other developers;Indu...  26.0    Man    No
# 5858          Tech articles written by other developers  34.0    Man    No
# 3765  Tech articles written by other developers;Indu...  27.0    Man    No
# 8455  Tech meetups or events in your area;Courses on...  28.0    Man    No
# 1546  Tech articles written by other developers;Cour...  28.0    Man    No
#
#                     Sexuality                     Ethnicity Dependents  \
# 3472  Straight / Heterosexual                   South Asian        Yes
# 5858  Straight / Heterosexual                           NaN        Yes
# 3765  Straight / Heterosexual  White or of European descent        Yes
# 8455  Straight / Heterosexual     Hispanic or Latino/Latina        Yes
# 1546  Straight / Heterosexual  White or of European descent         No
#
#                SurveyLength                  SurveyEase  \
# 3472  Appropriate in length                        Easy
# 5858  Appropriate in length  Neither easy nor difficult
# 3765  Appropriate in length                        Easy
# 8455               Too long                        Easy
# 1546  Appropriate in length                        Easy
#
#      NormalizedAnnualCompensation
# 3472                    1200000.0
# 5858                     110000.0
# 3765                      50000.0
# 8455                      62400.0
# 1546                      60000.0
#
# [5 rows x 86 columns]

# %% [markdown]
# What is the median **NormalizedAnnualCompensation**?

# %%
df['NormalizedAnnualCompensation'].describe()
# Out:
# count    1.058900e+04
# mean     6.133295e+06
# std      9.838157e+07
# min      0.000000e+00
# 25%      5.200000e+04
# 50%      1.000000e+05
# 75%      3.600000e+05
# max      8.400000e+09
# Name: NormalizedAnnualCompensation, dtype: float64
